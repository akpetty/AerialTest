# %% [markdown]
# # Aerial Intelligence exercise
#
# Author: Alek Petty / www.alekpetty.com / @alekpetty

# %% [markdown]
# # Approach
# - Use Python Pandas to read in and manipulate the two datasets provided
# - Use matplotlib to map/visualize the data
# - Run some simple statistics (linear regression) to check there is no simple solution
# (e.g. a variable that stands out for being a good predictor)
# - Finally we use a Random Forest implmentation in scikit-learn to try out and evaluate a more complex prediction framework
#
# Issues: It would have been nice to have more years of data to play with.
# It looks like the yields are very regional, and this is what dominates the signal
# (lat/lon, not the county etc). I've experimented with removing this information to try and understand if we can use just the atmospheric data to predict yields, independant of location, but the skill is a lot lower.

# %%
# Import our libraries
from pylab import *
# Use Pandas to read in and explore the datasets provided.
from pandas import DataFrame, read_csv
import pandas as pd
# %matplotlib inline

# %%
# Read in the 2 csv files 
# Initially tried using one as training and one as test data, 
# but here we explore combining and subsetting more randomly
df1=pd.read_csv('wheat-2013-supervised.csv')
df2=pd.read_csv('wheat-2014-supervised.csv')
df1.shape, df2.shape
# Out:
# ((177493, 26), (182549, 26))

# %%
# Simple data checks.
# E.g. check all yield vaules are real numbers (i.e. not NaNs)
np.size(np.where(np.isfinite(df1['Yield'])))
# Out:
# 177493

# %%
#Take a look at the dataset
df1.head(2)
#df1.describe()
# Out:
#   CountyName       State   Latitude   Longitude             Date  \
# 0      Adams  Washington  46.811686 -118.695237  11/30/2013 0:00
# 1      Adams  Washington  46.929839 -118.352109  11/30/2013 0:00
#
#    apparentTemperatureMax  apparentTemperatureMin  cloudCover  dewPoint  \
# 0                    35.7                   20.85         0.0     29.53
# 1                    35.1                   26.92         0.0     29.77
#
#    humidity  ...    precipTypeIsOther  pressure  temperatureMax  \
# 0      0.91  ...                    0   1027.13            35.7
# 1      0.93  ...                    0   1026.87            35.1
#
#    temperatureMin  visibility  windBearing  windSpeed        NDVI  \
# 0           27.48        2.46          214       1.18  134.110657
# 1           26.92        2.83          166       1.01  131.506592
#
#    DayInSeason  Yield
# 0            0   35.7
# 1            0   35.7
#
# [2 rows x 26 columns]

# %%
df1.describe()
# Out:
#             Latitude      Longitude  apparentTemperatureMax  \
# count  177493.000000  177493.000000           177493.000000
# mean       37.525355    -100.877849               54.836240
# std         4.918148       5.960510               23.827278
# min        27.803015    -120.914093              -39.970000
# 25%        34.135464    -101.294945               37.830000
# 50%        36.810364     -99.128028               58.880000
# 75%        38.945878     -97.352044               73.100000
# max        48.981928     -94.613571              177.320000
#
#        apparentTemperatureMin     cloudCover       dewPoint       humidity  \
# count           177493.000000  177493.000000  177493.000000  177493.000000
# mean                27.915526       0.071478      29.712311       0.593973
# std                 22.029381       0.138932      16.687710       0.163590
# min                -58.420000       0.000000     -36.090000       0.080000
# 25%                 14.310000       0.000000      19.600000       0.470000
# 50%                 26.560000       0.010000      27.850000       0.600000
# 75%                 42.200000       0.090000      38.890000       0.720000
# max                 77.180000       1.000000      75.180000       1.000000
#
#        precipIntensity  precipIntensityMax  precipProbability      ...        \
# count    177492.000000       177492.000000      177492.000000      ...
# mean          0.001158            0.010633           0.133540      ...
# std           0.004559            0.044782           0.253416      ...
# min           0.000000            0.000000           0.000000      ...
# 25%                NaN                 NaN                NaN      ...
# 50%                NaN                 NaN                NaN      ...
# 75%                NaN                 NaN                NaN      ...
# max           0.152900            2.054900           0.960000      ...
#
#        precipTypeIsOther       pressure  temperatureMax  temperatureMin  \
# count           177493.0  177239.000000   177493.000000   177493.000000
# mean                 0.0    1017.077664       57.547801       34.393113
# std                  0.0       8.607401       20.755273       17.801718
# min                  0.0     942.490000      -22.000000      -39.790000
# 25%                  0.0            NaN       43.350000       23.420000
# 50%                  0.0            NaN       58.880000       33.250000
# 75%                  0.0            NaN       73.100000       46.070000
# max                  0.0    1048.130000      105.200000       77.180000
#
#           visibility    windBearing      windSpeed           NDVI  \
# count  177463.000000  177493.000000  177493.000000  177493.000000
# mean        9.285829     191.165483       8.436830     146.346701
# std         1.281721     104.103600       4.767758      10.130267
# min         0.600000       0.000000       0.040000     117.000000
# 25%              NaN     127.000000       4.760000     137.876236
# 50%              NaN     192.000000       7.670000     147.225510
# 75%              NaN     275.000000      11.530000     152.935913
# max        10.000000     359.000000      31.730000     206.000000
#
#          DayInSeason          Yield
# count  177493.000000  177493.000000
# mean       92.633084      31.443024
# std        53.608768      15.214107
# min         0.000000       9.000000
# 25%        46.000000      17.300000
# 50%        93.000000      31.100000
# 75%       139.000000      43.100000
# max       185.000000      72.200000
#
# [8 rows x 23 columns]

# %%
# There are lots of columns, so let's take a look at the rows of just one of the columns
df1.iloc[[0]].T
# Out:
#                                       0
# CountyName                        Adams
# State                        Washington
# Latitude                        46.8117
# Longitude                      -118.695
# Date                    11/30/2013 0:00
# apparentTemperatureMax             35.7
# apparentTemperatureMin            20.85
# cloudCover                            0
# dewPoint                          29.53
# humidity                           0.91
# precipIntensity                       0
# precipIntensityMax                    0
# precipProbability                     0
# precipAccumulation                    0
# precipTypeIsRain                      0
# precipTypeIsSnow                      0
# precipTypeIsOther                     0
# pressure                        1027.13
# temperatureMax                     35.7
# temperatureMin                    27.48
# visibility                         2.46
# windBearing                         214
# windSpeed                          1.18
# NDVI                            134.111
# DayInSeason                           0
# Yield                              35.7

# %%
# If we wanted to/were able to use those columns as categorical data we could do the following:
#df1['CountyName'] = df1['CountyName'].astype('category')
#df1['State'] = df1['State'].astype('category')
#df1E['CountyNameNum']=df1.CountyName.cat.codes
#df1E['StateNum']=df1.State.cat.codes

#drop those 3 columns, as stated in the test, plus precipTypeIsOther which is just zero in both
df1.drop('CountyName',axis=1,inplace=True)
df1.drop('State',axis=1,inplace=True)
df1.drop('Date',axis=1,inplace=True)
df1.drop('precipTypeIsOther',axis=1,inplace=True)
#df1.head(10)
df2.drop('CountyName',axis=1,inplace=True)
df2.drop('State',axis=1,inplace=True)
df2.drop('Date',axis=1,inplace=True)
df2.drop('precipTypeIsOther',axis=1,inplace=True)

# %%
# Made this an if statement as matplotlib can slow down the notebook for some reason..
plot_map=1
if (plot_map==1):
    # Plot figures in the Notebook
    
    # For mapping
    from mpl_toolkits.basemap import Basemap
    # Styles
    import matplotlib.pyplot as plt
    plt.style.available
    plt.style.use(u'ggplot')
    from matplotlib.pyplot import rc
    plt.rcParams['legend.fontsize']=8
    plt.rcParams['font.size']=7
    # Map some of the yields to see where we are..
    # Use a Lambert Conformal map for now
    m = Basemap(llcrnrlon=-119, llcrnrlat=22, urcrnrlon=-64,
      urcrnrlat=49, projection='lcc', lat_1=33, lat_2=45,
      lon_0=-95, resolution='h', area_thresh=10000)

    var=np.array(df1['Yield'])
    lons=np.array(df1['Longitude'])
    lats=np.array(df1['Latitude'])
    xpts, ypts = m(lons, lats)

    var2=np.array(df2['Yield'])
    lons2=np.array(df2['Longitude'])
    lats2=np.array(df2['Latitude'])
    xpts2, ypts2 = m(lons2, lats2)

# %%
if (plot_map==1):
    # Plot data for the two years
    fig =figure(figsize=(14,7))
    ax1=subplot(121)
    im1 = m.scatter(xpts, ypts, c=var, zorder=2)
    m.drawparallels(np.arange(25,65,20))
    m.drawmeridians(np.arange(-120,-40,20))
    m.drawcoastlines()
    #m.fillcontinents()
    ax1.annotate('2013', xy=(0.02, 1.02), fontsize=10,xycoords='axes fraction')
    ax2=subplot(122)
    im2 = m.scatter(xpts2, ypts2, c=var2, zorder=2)
    m.drawparallels(np.arange(25,65,20))
    m.drawmeridians(np.arange(-120,-40,20))
    m.drawcoastlines()
    #m.fillcontinents()
    ax2.annotate('2014', xy=(0.02, 1.02), fontsize=10, xycoords='axes fraction')
    plt.show()

# %% [markdown]
# We can see broadly similar data locations, with some regionality in yields clearly observable

# %%
# Uncomment if you want to use Pandas for viz. Seaborn (below) seems a bit better...
#plot scatters of yield against all other columns for this subset
#dfS.plot(style="x",x='Yield',layout=(-1, 4),
#         sharex=True, alpha=0.5, subplots=True, figsize=(12, 12));
#df.plot(kind='scatter',y='Yield',subplots=True)
#plt.show()

#dfS.plot(kind='scatter',x='apparentTemperatureMax', y='Yield', 
#        marker='x',alpha=0.5, subplots=True)

# %%
# Genrerate a random subset of the data to speed up plotting.
# Probably best to run with all data later.
dfS=df1.sample(500)
dfS.head(2)
# Out:
#         Latitude  Longitude  apparentTemperatureMax  apparentTemperatureMin  \
# 54048  38.985438 -98.048331                   54.84                   29.83
# 14667  29.076426 -98.925682                   62.73                   24.43
#
#        cloudCover  dewPoint  humidity  precipIntensity  precipIntensityMax  \
# 54048        0.04     27.75      0.51              0.0                 0.0
# 14667        0.00     26.88      0.52              0.0                 0.0
#
#        precipProbability  ...    precipTypeIsSnow  pressure  temperatureMax  \
# 54048                0.0  ...                   0   1014.88           54.84
# 14667                0.0  ...                   0   1027.36           62.73
#
#        temperatureMin  visibility  windBearing  windSpeed        NDVI  \
# 54048           36.86        10.0          296       8.60  147.160248
# 14667           30.23        10.0          324       2.72  153.222412
#
#        DayInSeason  Yield
# 54048           56   23.3
# 14667           15   53.5
#
# [2 rows x 22 columns]

# %%
# Use Seaborn for viz
# Seems a bit better for automatically generating proper axes bounds...
import seaborn as sns
colNames=list(dfS.columns.values)
# If we want to remove some columns...
colNames=colNames[2:4]+colNames[5:]
# any groupings using Yield as a hue?
#g = sns.pairplot(dfS, hue="Yield")
g = sns.pairplot(dfS, y_vars=colNames, x_vars=["Yield"], size=4)

# %% [markdown]
# Not clear from just looking at the data if there is any link between yield and the various metrics, but let's try some simple regressions...

# %%
#Pearson correlation coefficient
a=df1.corr()
a['Yield']
#df1.head(2)
# Out:
# Latitude                  0.364207
# Longitude                -0.206993
# apparentTemperatureMax   -0.140315
# apparentTemperatureMin   -0.049998
# cloudCover                0.069506
# dewPoint                  0.011607
# humidity                  0.204990
# precipIntensity           0.046477
# precipIntensityMax        0.030030
# precipProbability         0.111941
# precipAccumulation        0.024285
# precipTypeIsRain          0.108773
# precipTypeIsSnow          0.079263
# pressure                  0.063212
# temperatureMax           -0.152702
# temperatureMin           -0.060512
# visibility               -0.092501
# windBearing               0.065064
# windSpeed                -0.106314
# NDVI                     -0.170673
# DayInSeason              -0.001171
# Yield                     1.000000
# Name: Yield, dtype: float64

# %%
#Pearson correlation coefficient
a=df2.corr()
a['Yield']   
#abs(a['Yield']).argsort()
#df1.head(2)
# Out:
# Latitude                  0.486362
# Longitude                -0.309373
# apparentTemperatureMax   -0.165742
# apparentTemperatureMin   -0.146381
# cloudCover               -0.007271
# dewPoint                 -0.158787
# humidity                 -0.026934
# precipIntensity          -0.015459
# precipIntensityMax       -0.020094
# precipProbability         0.010231
# precipAccumulation        0.042825
# precipTypeIsRain          0.007165
# precipTypeIsSnow          0.064623
# pressure                  0.045568
# temperatureMax           -0.172160
# temperatureMin           -0.153430
# visibility                0.020855
# windBearing               0.082784
# windSpeed                -0.065331
# NDVI                     -0.187925
# DayInSeason              -0.001328
# Yield                     1.000000
# Name: Yield, dtype: float64

# %%
# No obvious strong correlations with single metrics, except lat/lon and humidity..?

# %% [markdown]
# # Random Forest
# - Use the scikit-learn Random Forest alogirthm
# - Need to clean up the data first and generate training/test data.
# - Did originally use the different years as Train/Test, but I've decided it best to combine years and subset using a fraction of the total data

# %%
# Combine the two years
dfAll = pd.concat([df1, df2])
dfTrain=dfAll.sample(frac=0.8,random_state=200)
dfTest=dfAll.drop(dfTrain.index)
#dfTrain.shape, dfTest.shape

# Get training/test yield datasets
yieldTrain=dfTrain['Yield']
yieldTest=dfTest['Yield']
# Get lon/Lat of the test yields to plot out later
lonT=dfTest['Longitude'][dfTest.index]
latT=dfTest['Latitude'][dfTest.index]

# Drop the yield column from the fitting datasets
dfTrain=dfTrain.drop('Yield',axis=1)
dfTest=dfTest.drop('Yield',axis=1)

# Drop Lat/Lon to make it a harder (fairer?) test..
#dfTrain=dfTrain.drop('Longitude',axis=1)
#dfTrain=dfTrain.drop('Latitude',axis=1)
#dfTest=dfTest.drop('Longitude',axis=1)
#dfTest=dfTest.drop('Latitude',axis=1)
dfTrain.shape, dfTest.shape
# Out:
# ((288034, 21), (15132, 21))

# %%
def scale_all_features(dfT):  
    # Function to normalize all columns in a Pandas dataFrame
    features = list(dfT.columns)
    dfT[features] = dfT[features].apply(lambda x: (x-x.min())/(x.max()-x.min()), axis=0)  
    return dfT

# %%
# Normalize tdfTrain = scale_all_features(dfTrain)
dfTest = scale_all_features(dfTest)
dfTrain = scale_all_features(dfTrain)
dfTest.head(2)
dfTrain.head(2)
# Out:
#         Latitude  Longitude  apparentTemperatureMax  apparentTemperatureMin  \
# 120055  0.920417   0.082444                0.473969                0.686839
# 56210   0.515503   0.954072                0.518808                0.547978
#
#         cloudCover  dewPoint  humidity  precipIntensity  precipIntensityMax  \
# 120055        0.31  0.581909  0.483516           0.0086            0.003593
# 56210         0.01  0.564993  0.637363           0.0000            0.000000
#
#         precipProbability     ...       precipTypeIsRain  precipTypeIsSnow  \
# 120055           0.556701     ...                    1.0               0.0
# 56210            0.000000     ...                    0.0               0.0
#
#         pressure  temperatureMax  temperatureMin  visibility  windBearing  \
# 120055  0.638173        0.603692        0.679430    0.993711     0.635097
# 56210   0.692638        0.674213        0.532468    0.901468     0.777159
#
#         windSpeed      NDVI  DayInSeason
# 120055   0.291167  0.408646     0.675676
# 56210    0.168139  0.404956     0.308108
#
# [2 rows x 21 columns]

# %%
# Do something with the NaN values. Should think about this more.
features = list(dfTrain.columns)
for x in features:
    # Fill the nan values with the median value, or fitting model isn't happy.
    dfTrain[x].fillna(dfTrain[x].median(), inplace=True)
    dfTest[x].fillna(dfTest[x].median(), inplace=True)

# %%
# Yields need to be integers (or strings) to be used in the random forest classifier
yieldTrainS = np.asarray(yieldTrain, dtype="int")
yieldTestS = np.asarray(yieldTest, dtype="int")
#yieldTrainS = np.asarray(yieldTrain, dtype="|S6")
#yieldTestS = np.asarray(yieldTest, dtype="|S6")
yieldTestS
# Out:
# array([13, 16, 32, ..., 23, 23, 50])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import StratifiedKFold
from sklearn.grid_search import GridSearchCV

# Create Random Forest
forest = RandomForestClassifier(n_estimators = 19, n_jobs=-1)

# Fit Random Forest classifier
model = forest.fit(dfTrain,yieldTrainS)

# Predict using this forest
guess1 = model.predict(dfTest)
guess1
# Out:
# array([13, 14, 45, ..., 23, 23, 50])

# %%
def rms(var):
    return sqrt(sum([x**2 for x in var])/size(var))

from scipy import stats
slope, intercept, r, prob, stderr = stats.linregress(guess1,yieldTestS)
rmse=rms(guess1-yieldTestS)
r, rmse
# Out:
# (0.90811370287844817, 5.7445626465380286)

# %%
cross_validation = StratifiedKFold(yieldTrainS, n_folds=5)
parameter_grid = {   
                 'n_estimators': [40, 60, 80],
                 'criterion': ['gini', 'entropy']
                 }
grid_search = GridSearchCV(forest,param_grid=parameter_grid)
                           #cv=cross_validation)
grid_search.fit(dfTrain, yieldTrainS)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
guess2 = grid_search.predict(dfTest)
guess2
slope, intercept, r, prob, stderr = stats.linregress(guess2, yieldTestS)
rmse=rms(guess2-yieldTestS)
r, rmse
# Out:
# Best score: 0.903660678948
# Best parameters: {'n_estimators': 80, 'criterion': 'entropy'}
# (0.95070691220896242, 4.1231056256176606)

# %%
# Look at the scatter plot of guess and actual
fig =figure(figsize=(8,8))
scatter(guess2, yieldTestS)
plot(np.linspace(10,70,10), intercept+ slope*np.linspace(10,70,10))

# %%
xptsT, yptsT = m(np.array(lonT), np.array(latT))

# %%
# Plot data for the test data and predicted
fig =figure(figsize=(14,7))
ax1=subplot(121)
im1 = m.scatter(xptsT, yptsT, c=yieldTestS, zorder=2)
m.drawparallels(np.arange(25,65,20))
m.drawmeridians(np.arange(-120,-40,20))
m.drawcoastlines()
#m.fillcontinents()
ax1.annotate('Truth', xy=(0.02, 1.02), fontsize=10,xycoords='axes fraction')
ax2=subplot(122)
im2 = m.scatter(xptsT, yptsT, c=guess2, zorder=2)
m.drawparallels(np.arange(25,65,20))
m.drawmeridians(np.arange(-120,-40,20))
m.drawcoastlines()
#m.fillcontinents()
ax2.annotate('Prediction', xy=(0.02, 1.02), fontsize=10, xycoords='axes fraction')
plt.show()

# %% [markdown]
# # Final thoughts
# - The random forest gives a decent correlation/RMSE, although it's tough to tell what might be seen as a good/skillful prediction.
# - The maps don't look great, but I think we need more data, or perhaps alterantive data sources (e.g. crop information?)
